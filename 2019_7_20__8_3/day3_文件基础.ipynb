# %%
f=open(r'C:\Users\nswdwy_yu\Desktop','1.txt')
txt=f.read()
print(txt)
f.close
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-2afca1858373> in <module>()
# ----> 1 f=open(r'C:\Users\nswdwy_yu\Desktop','1.txt')
#       2 txt=f.read()
#       3 print(txt)
#       4 f.close
#
# ValueError: invalid mode: '1.txt'

# %%
import csv
filepath2=r'C:\Users\nswdwy_yu\Desktop\iris.csv'

# %%
with open(filepath2,'r')as f:
    reader=csv.reader(f)
    for x in reader:
        print(x)
# Out:
# ['', 'Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']
# ['1', '5.1', '3.5', '1.4', '0.2', 'setosa']
# ['2', '4.9', '3', '1.4', '0.2', 'setosa']
# ['3', '4.7', '3.2', '1.3', '0.2', 'setosa']
# ['4', '4.6', '3.1', '1.5', '0.2', 'setosa']
# ['5', '5', '3.6', '1.4', '0.2', 'setosa']
# ['6', '5.4', '3.9', '1.7', '0.4', 'setosa']
# ['7', '4.6', '3.4', '1.4', '0.3', 'setosa']
# ['8', '5', '3.4', '1.5', '0.2', 'setosa']
# ['9', '4.4', '2.9', '1.4', '0.2', 'setosa']
# ['10', '4.9', '3.1', '1.5', '0.1', 'setosa']
# ['11', '5.4', '3.7', '1.5', '0.2', 'setosa']
# ['12', '4.8', '3.4', '1.6', '0.2', 'setosa']
# ['13', '4.8', '3', '1.4', '0.1', 'setosa']
# ['14', '4.3', '3', '1.1', '0.1', 'setosa']
# ['15', '5.8', '4', '1.2', '0.2', 'setosa']
# ['16', '5.7', '4.4', '1.5', '0.4', 'setosa']
# ['17', '5.4', '3.9', '1.3', '0.4', 'setosa']
# ['18', '5.1', '3.5', '1.4', '0.3', 'setosa']
# ['19', '5.7', '3.8', '1.7', '0.3', 'setosa']
# ['20', '5.1', '3.8', '1.5', '0.3', 'setosa']
# ...

# %%
with open(filepath2,'r')as f:
    reader=csv.DictReader(f)
    for x in reader:
        print(x)
# Out:
# OrderedDict([('', '1'), ('Sepal.Length', '5.1'), ('Sepal.Width', '3.5'), ('Petal.Length', '1.4'), ('Petal.Width', '0.2'), ('Species', 'setosa')])
# OrderedDict([('', '2'), ('Sepal.Length', '4.9'), ('Sepal.Width', '3'), ('Petal.Length', '1.4'), ('Petal.Width', '0.2'), ('Species', 'setosa')])
# OrderedDict([('', '3'), ('Sepal.Length', '4.7'), ('Sepal.Width', '3.2'), ('Petal.Length', '1.3'), ('Petal.Width', '0.2'), ('Species', 'setosa')])
# OrderedDict([('', '4'), ('Sepal.Length', '4.6'), ('Sepal.Width', '3.1'), ('Petal.Length', '1.5'), ('Petal.Width', '0.2'), ('Species', 'setosa')])
# OrderedDict([('', '5'), ('Sepal.Length', '5'), ('Sepal.Width', '3.6'), ('Petal.Length', '1.4'), ('Petal.Width', '0.2'), ('Species', 'setosa')])
# OrderedDict([('', '6'), ('Sepal.Length', '5.4'), ('Sepal.Width', '3.9'), ('Petal.Length', '1.7'), ('Petal.Width', '0.4'), ('Species', 'setosa')])
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(filepath2)
print(df)
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# 5             6           5.4          3.9           1.7          0.4
# 6             7           4.6          3.4           1.4          0.3
# 7             8           5.0          3.4           1.5          0.2
# 8             9           4.4          2.9           1.4          0.2
# 9            10           4.9          3.1           1.5          0.1
# 10           11           5.4          3.7           1.5          0.2
# 11           12           4.8          3.4           1.6          0.2
# ...

# %%
df.to_csv(r'C:\Users\nswdwy_yu\Desktop\xiugai.csv')

# %%
df.to_csv(r'C:\Users\nswdwy_yu\Desktop\xiugai2.csv',index=False)

# %%
import os
os.name
# Out:
# 'nt'

# %%
print(os.getcwd())
# Out:
# C:\Users\nswdwy_yu

# %%
os.listdir(r'C:\Users\nswdwy_yu')
# Out:
# ['.dotnet',
#  '.eclipse',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.p2',
#  '.PyCharmCE2018.3',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Day1_practice1.ipynb',
#  'Day1_Practice2.ipynb',
#  'Day2_practice1.ipynb',
#  'Day2_practice2.ipynb',
#  'day2_practice3.ipynb',
#  'day3_函数及模块.ipynb',
#  'day3_文件基础.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'gsview32.ini',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'Note',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{4e074668-0c1c-11e7-a943-e41d2d718a20}.TM.blf',
#  'NTUSER.DAT{4e074668-0c1c-11e7-a943-e41d2d718a20}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{4e074668-0c1c-11e7-a943-e41d2d718a20}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
# ...

# %%
os.chdir(r'C:\Users\nswdwy_yu\Desktop')
with open(r'iris.csv','r')as f:
    a=f.read()
    print(type(a))
    print(a)
# Out:
# <class 'str'>
# "","Sepal.Length","Sepal.Width","Petal.Length","Petal.Width","Species"
# "1",5.1,3.5,1.4,0.2,"setosa"
# "2",4.9,3,1.4,0.2,"setosa"
# "3",4.7,3.2,1.3,0.2,"setosa"
# "4",4.6,3.1,1.5,0.2,"setosa"
# "5",5,3.6,1.4,0.2,"setosa"
# "6",5.4,3.9,1.7,0.4,"setosa"
# "7",4.6,3.4,1.4,0.3,"setosa"
# "8",5,3.4,1.5,0.2,"setosa"
# "9",4.4,2.9,1.4,0.2,"setosa"
# "10",4.9,3.1,1.5,0.1,"setosa"
# "11",5.4,3.7,1.5,0.2,"setosa"
# "12",4.8,3.4,1.6,0.2,"setosa"
# "13",4.8,3,1.4,0.1,"setosa"
# "14",4.3,3,1.1,0.1,"setosa"
# "15",5.8,4,1.2,0.2,"setosa"
# "16",5.7,4.4,1.5,0.4,"setosa"
# "17",5.4,3.9,1.3,0.4,"setosa"
# "18",5.1,3.5,1.4,0.3,"setosa"
# "19",5.7,3.8,1.7,0.3,"setosa"
# "20",5.1,3.8,1.5,0.3,"setosa"
# "21",5.4,3.4,1.7,0.2,"setosa"
# "22",5.1,3.7,1.5,0.4,"setosa"
# "23",4.6,3.6,1,0.2,"setosa"
# "24",5.1,3.3,1.7,0.5,"setosa"
# "25",4.8,3.4,1.9,0.2,"setosa"
# "26",5,3,1.6,0.2,"setosa"
# "27",5,3.4,1.6,0.4,"setosa"
# "28",5.2,3.5,1.5,0.2,"setosa"
# "29",5.2,3.4,1.4,0.2,"setosa"
# ...
