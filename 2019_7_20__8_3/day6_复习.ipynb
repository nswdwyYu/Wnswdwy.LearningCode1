# %%
import numpy as np
import matplotlib.pyplot as plt

#导入数据
data = np.load('C:/Users/nswdwy_yu/Desktop/国民经济核算季度数据.npz')
name = data['columns']
values = data['values']

#设置参数
plt.rcParams['lines.linestyle']='-' #取值可为‘-’ '-.' '--'
plt.rcParams['lines.linewidth']=2   #取值为0-10  默认1.5
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

#设置图表的各内容
data2=np.arange(0,np.pi*2,0.01)
#第一步 绘制大画布
p_big=plt.figure(figsize=(11,10),dpi=200)
#第二步   绘制第1个子画布
ax_fist=p_big.add_subplot(2,2,1)
label_first = ['第1产业','第2产业','第3产业']
plt.title('2000年第1季度三大产业的值')
plt.xlabel('产业')
plt.ylabel('生产总值')
plt.xlim()
plt.ylim((0,12000))
plt.xticks(range(3),label)
plt.yticks(range(0,12000,1000))
#画图
plt.bar(range(3),values[0,3:6],width = 0.5,color = 'r')

#第2个子图
ax_second=p_big.add_subplot(2,2,2)
label_second = ['第1产业','第2产业','第3产业']
plt.title('2017年第1季度三大产业的值')
plt.xlabel('产业')
plt.ylabel('生产总值')
plt.xlim()
plt.ylim((0,12000))
plt.xticks(range(3),label_second)
plt.yticks(range(0,12000,1000))
#画图
plt.bar(range(3),values[-1,3:6],width = 0.5,color = 'r')

#第3个子图
ax_thrid=p_big.add_subplot(2,2,3)
label_thrid = ['第1产业','第2产业','第3产业']
plt.title('2000年第1季度所以产业的值')
plt.xlabel('产业')
plt.ylabel('生产总值')
plt.xlim()
plt.ylim((0,12000))
plt.xticks(range(3),label_thrid)
plt.yticks(range(0,12000,1000))
#画图
plt.bar(range(9),values[0,6:],width = 0.5,color = 'g')

#第4个子图
ax_fourth=p_big.add_subplot(2,2,4)
label_fourth = ['第1产业','第2产业','第3产业']
plt.title('2017年第1季度所以产业的值')
plt.xlabel('产业')
plt.ylabel('生产总值')
plt.xlim()
plt.ylim((0,12000))
plt.xticks(range(3),label_fourth)
plt.yticks(range(0,12000,1000))
#画图
plt.bar(range(9),values[0,6:],width = 0.5,color = 'g')


#plt.pie(values[-1,3:6],explode=[0.1,0.1,0.1],labels=label,autopct ='%1.1f%%')
#图例
#plt.legend()
#保存并显示
plt.savefig('C:/Users/nswdwy_yu/Desktop/scatter.jpg')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#导入数据
data = np.load('C:/Users/nswdwy_yu/Desktop/国民经济核算季度数据.npz')
name = data['columns']
values = data['values']
name
# Out:
# array(['序号', '时间', '国内生产总值_当季值(亿元)', '第一产业增加值_当季值(亿元)', '第二产业增加值_当季值(亿元)',
#        '第三产业增加值_当季值(亿元)', '农林牧渔业增加值_当季值(亿元)', '工业增加值_当季值(亿元)',
#        '建筑业增加值_当季值(亿元)', '批发和零售业增加值_当季值(亿元)', '交通运输、仓储和邮政业增加值_当季值(亿元)',
#        '住宿和餐饮业增加值_当季值(亿元)', '金融业增加值_当季值(亿元)', '房地产业增加值_当季值(亿元)',
#        '其他行业增加值_当季值(亿元)'], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt

#导入数据
data = np.load('C:/Users/nswdwy_yu/Desktop/国民经济核算季度数据.npz')
name = data['columns']
values = data['values']

#设置参数
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False
#绘制画布
plt.figure(figsize = (10,8) ,dpi = 80)
#设置图表的各内容
label = ['第1产业','第2产业','第3产业']
plt.title('2000年第1季度数据状况')
plt.xlabel('产业')
plt.ylabel('生产总值')
plt.xlim()
plt.ylim((0,120000))
plt.xticks(range(3),label)
plt.yticks(range(0,140000,20000))
#画图
plt.bar(range(3),values[-1,3:6],width = 0.5,color = 'r')

#plt.pie(values[-1,3:6],explode=[0.1,0.1,0.1],labels=label,autopct ='%1.1f%%')
#图例
#plt.legend()
#保存并显示
plt.savefig('C:/Users/nswdwy_yu/Desktop/scatter.jpg')
plt.show()
